# %%
import pandas as pd

# %%
file_path = "ANALYSES MEV 6.1_2024 bon (1).xlsb"

# %%
xlsb = pd.ExcelFile(file_path, engine="pyxlsb")

# %%
# Vérifier les noms des feuilles
print(xlsb.sheet_names)
# Out:
# ['SE', 'BASE POPULATION', 'Situation cas non validés', 'zero doses_Dose inconnue', 'Suvi_contact', 'Non Geolocalisé', 'Examens de suivi-attendus', 'Suivi_MEV_2022', 'Suivi_MEV_2024', 'Carte_Performance', '03_NOTIF_MEV_EVENT', 'BASE_PFA', 'nouveaux_indicateurs', 'Feuil3', 'nouveaux_indicateurs_12M', 'Feuil4', '11_SYNTHESES PFA 12M', 'RESULTS PFA REGION', 'RESULTS PFA PAR DS', 'RESULTS PFA PAR_AN-1', '06_SYNTHESES PFA', '09_DELAIS', 'DELAIS_new', 'STATUT VACCINAL PFA 0-59 mois', '16_Personnes ayant détecté', 'Delais_Notification', 'PLUS_LONGS_DELAIS_SANS_PFA', 'DS SILENCIEUX', 'D6&D7', 'EXAMEN_SUIVI', 'Feuil2', 'BASE_PFA_1', 'Nvx_Indicateurs', 'Competude_MAPE', 'Promptitude_MAPE', 'CAE_CPC_LAB', 'CAE_PFA_2023_03_W4', '10DS PRIORITAIRES', 'Classification PFA', 'Courbes_epidemiques', 'BASE_SE', '17&18_RESULTATS SE', 'LAB ROUG', 'Courbe_Epid', 'Suivi_Igm+', 'BASE_ROUGEOLE', 'SYNTHESES ROUGEOLE', 'SYNTHESES ROUGEOLE new', 'MAPE_Rougeole', 'EPIDEMIE_SUSPECTE_RG_PAR_DS', 'Courbe', 'ROUGEOLE 
# ...

# %%
# Charger les premières lignes de la feuille "STATUT VACCINAL"
df_vaccinal = pd.read_excel(xlsb, sheet_name="STATUT VACCINAL", nrows=5)
print(df_vaccinal.head())
# Out:
#   semaine épidémiologique                         21              Unnamed: 2  \
# 0                    date                      44697                     NaN
# 1                     NaN                        NaN                     NaN
# 2           TRANCHE D'AGE  Nombre de cas investigués  Nombre de cas positifs
# 3                0-8 mois                        440                     271
# 4               9-59 mois                       2388                    1582
#
#                Période 1                      44200           44703  \
# 0                    NaN                        NaN             NaN
# 1                    NaN                        NaN             NaN
# 2  Cas positifs vaccinés  Cas positifs non vaccinés  % cas positifs
# 3                     27                       -244         9.75522
# 4                    463                      -1119       56.947444
#
#                    Période 2  44199  44338
# 0                        NaN    NaN    NaN
# ...

# %%
# Charger les premières lignes de la feuille "BASE POPULATION"
df_population = pd.read_excel(xlsb, sheet_name="BASE POPULATION", nrows=5)
print(df_population.head())
# Out:
#   Country_Code Province_Name District_Name District_Code Province_Code  \
# 0          CAE        CENTRE     MBANDJOCK           MBJ           CEN
# 1          CAE        CENTRE      MBANKOMO           MBK           CEN
# 2          CAE        CENTRE          MFOU           MFO           CEN
# 3          CAE        CENTRE      MONATELE           MON           CEN
# 4          CAE        CENTRE   NANGA EBOKO           NAN           CEN
#
#    DistrictPopulation  LiveBirths  SurvivingInfants  Under15Pop  CBAWomen  HF  \
# 0               59954        2468              2036       28378     13789 NaN
# 1               30067        1238              1021       14232      6915 NaN
# 2               74902        3083              2543       35454     17228 NaN
# 3               67225        2767              2283       31820     15462 NaN
# 4               92636        3813              3146       43848     21306 NaN
#
#    NumofexpectedReport  Year  UniqueKey  RECSTATUS  Pregnant_Women  \
# ...
